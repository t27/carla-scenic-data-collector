# %%
import pandas as pd

# %%
orig = pd.read_csv("../recordings/round_0.csv")
recording = pd.read_csv("../replay_round_0.csv")

# %%
orig
# Out:
#         frame_id   id                       type_id       pos_x       pos_y  \
# 0              0   11                  traffic.stop  148.487900  -14.842549
# 1              0   12                  traffic.stop  215.168533   62.527878
# 2              0   13                  traffic.stop   15.863537  130.585617
# 3              0   14                  traffic.stop   -5.622720  189.834396
# 4              0   15                  traffic.stop   -9.106436  189.860626
# ...          ...  ...                           ...         ...         ...
# 159688      1499  319  vehicle.dodge_charger.police  -24.619755    6.242687
# 159689      1499  320       vehicle.bmw.grandtourer -145.456726   -7.497466
# 159690      1499  321            vehicle.audi.etron  203.695114  179.711136
# 159691      1499  322            vehicle.audi.etron   32.851929   -4.568919
# 159692      1499  324       vehicle.mustang.mustang  170.317673   68.340813
#
# ...

# %%
recording
# Out:
#         frame_id   id                       type_id       pos_x       pos_y  \
# 0              0   11               traffic.unknown   -5.680000  187.781494
# 1              0   12               traffic.unknown -145.589996   76.869995
# 2              0   13               traffic.unknown -136.059998   58.109997
# 3              0   14                  traffic.stop  -48.944572  187.171600
# 4              0   15                  traffic.stop  170.639999   80.269997
# ...          ...  ...                           ...         ...         ...
# 159688      1499  319  vehicle.dodge_charger.police  -24.832729    6.016594
# 159689      1499  320       vehicle.bmw.grandtourer -145.457306   -7.166800
# 159690      1499  321            vehicle.audi.etron  204.189285  179.403259
# 159691      1499  322            vehicle.audi.etron   33.161343   -4.563715
# 159692      1499  324       vehicle.mustang.mustang  170.369431   68.661064
#
# ...
